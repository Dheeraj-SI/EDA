# %%
#Import the necessary librari
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style='darkgrid')

# %%
#read the csv file into pandas dataframe
df = pd.read_csv('zomato.csv',encoding = 'latin-1')

# %% [markdown]
# #

# %% [markdown]
# # High level understanding of data

# %%
#Check data size and sample rows
print(df.shape)
df.head()
# Out:
# (9551, 21)
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#checking the columns
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#dataframe non null values and data type information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#checking the distribution of data
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#check the missing values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Cusines has 9 missing values

# %%
#missing values columns list
miss_val_cols = [feature for feature in df.columns if df[feature].isnull().sum() > 0]
miss_val_cols
# Out:
# ['Cuisines']

# %%
#Visualizing Null values in heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Importing country code data
df_country_code = pd.read_excel('Country-Code.xlsx')

# %%
#country code data
df_country_code
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# This data has information of country code for 14 different countries

# %%
#merging country code data with the zomato data
df = pd.merge(df,df_country_code,on = 'Country Code',how='inner')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #

# %% [markdown]
# # Data distribution / Univariate Analysis / Multivariate Analysis

# %% [markdown]
# #

# %%
#Overall relationship between different variables
sns.pairplot(df)

# %% [markdown]
# #

# %% [markdown]
# ### Country distribution

# %%
#Checking the distribution of countries
country_names = df.Country.value_counts().index
country_val = df.Country.value_counts().values
plt.pie(labels = country_names, x=country_val)
# Out:
# ([<matplotlib.patches.Wedge at 0x212934784f0>,
# ...
#  [Text(-1.052256163793291, 0.3205572737577906, 'India'),
#   Text(0.9911329812843455, -0.477132490415823, 'United States'),
#   Text(1.0572858296119743, -0.3035567072257165, 'United Kingdom'),
#   Text(1.070138816916019, -0.2545641619112621, 'Brazil'),
#   Text(1.0793506814479759, -0.21213699926648824, 'UAE'),
#   Text(1.086881147244973, -0.16937937230799818, 'South Africa'),
#   Text(1.0918635911832035, -0.1335436192729486, 'New Zealand'),
#   Text(1.0947903814016446, -0.10692998078388304, 'Turkey'),
#   Text(1.096631023945382, -0.08602556201794338, 'Australia'),
#   Text(1.0978070729776455, -0.06942355882735218, 'Phillipines'),
#   Text(1.0986791544015209, -0.05388984768543213, 'Indonesia'),
#   Text(1.0993059848742366, -0.039068550263413035, 'Singapore'),
#   Text(1.0997248508282123, -0.02460187941736628, 'Qatar'),
#   Text(1.0999533462179636, -0.010130949802716446, 'Sri Lanka'),
# ...

# %%
#Top 3 countries
plt.pie(labels = country_names[:3], x=country_val[:3], autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21290e13d00>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# ##### India(94.39%), USA(4.73%) and United Kingdom(0.87%) is where more zomato restaurants are found

# %% [markdown]
# #

# %% [markdown]
# ### Customer rating information

# %% [markdown]
# Considering Aggregate rating, Rating color, Rating text to check the count and distribution

# %%
ratings =df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns = {0:'Rating count'})
print(ratings.shape)
ratings
# Out:
# (33, 4)
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# ...

# %% [markdown]
# #### Ratings
# ##### 4.5 - 4.9 - Excellent
# ##### 4.0 - 4.5 - Very Good
# ##### 3.5 - 3.9 - Good
# ##### 2.5 - 3.4 - Average
# ##### 0 - 2.5 - Poor

# %% [markdown]
# #

# %%
plt.figure(figsize=(10,8))
sns.barplot( x = 'Aggregate rating', y = 'Rating count', data = ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating count'>

# %% [markdown]
# ##### 1. Most of the records have 0 rating
# ##### 2. Maximum number of ratings are between 2.9 to 4.0

# %% [markdown]
# #

# %%
#Checking the distribution of Rating text
plt.figure(figsize=(10,6))
sns.countplot(x = 'Rating text', data = df)
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='count'>

# %% [markdown]
# ##### 1 Most of the ratings are average
# ##### 2 There are significant counts for Good and Not Rated records
# ##### 3 Only few records are Highly or Poorly rated

# %% [markdown]
# #

# %%
#Countries name that has given 0 ratings
df_zero = df.groupby(['Country','Aggregate rating']).size().reset_index().rename({0:'count'})
df_zero[df_zero['Aggregate rating']==0]
# Out:
#             Country  Aggregate rating     0
# 12           Brazil               0.0     5
# 37            India               0.0  2139
# 180  United Kingdom               0.0     1
# 200   United States               0.0     3

# %%
#Checking the currency of each country
df.groupby(['Country','Currency']).count().reset_index()[['Country','Currency']]
# Out:
#            Country                Currency
# 0        Australia               Dollar($)
# 1           Brazil      Brazilian Real(R$)
# 2           Canada               Dollar($)
# 3            India      Indian Rupees(Rs.)
# 4        Indonesia  Indonesian Rupiah(IDR)
# 5      New Zealand           NewZealand($)
# 6      Phillipines        Botswana Pula(P)
# 7            Qatar         Qatari Rial(QR)
# 8        Singapore               Dollar($)
# 9     South Africa                 Rand(R)
# 10       Sri Lanka   Sri Lankan Rupee(LKR)
# 11          Turkey        Turkish Lira(TL)
# 12             UAE      Emirati Diram(AED)
# 13  United Kingdom              Pounds(£)
# 14   United States               Dollar($)

# %%
df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
#Visualizing cities distribution in india
df_ind_cities = df[df['Country'] == 'India'].groupby('City').size().reset_index().sort_values(by=0,ascending=False).reset_index()
df_ind_cities.drop('index',axis=1,inplace=True)
df_ind_cities.rename(columns = {0:'Count'},inplace=True)
df_ind_cities.head()
# Out:
#         City  Count
# 0  New Delhi   5473
# 1    Gurgaon   1118
# 2      Noida   1080
# 3  Faridabad    251
# 4  Ghaziabad     25

# %%
#Plotting the graph for citywise records
plt.figure(figsize=(10,6))
df_ind_cities[0:10].plot(kind='barh', x='City', y='Count', legend=False)
# Out:
# <AxesSubplot:ylabel='City'>

# %% [markdown]
# ##### In India New Delhi has most records followed by Gurgaon, Noida and Faridabad amoing top 4

# %% [markdown]
# #

# %%
#Plotting top localities 
plt.figure(figsize=(10,5))
df.Locality.value_counts()[0:10].plot(kind='barh', color = 'r')
plt.xlabel('Count')
plt.title('Localities\n')
# Out:
# Text(0.5, 1.0, 'Localities\n')

# %% [markdown]
# #

# %% [markdown]
# ### Cuisines

# %%
print(df.Cuisines.nunique())
df.Cuisines.value_counts()
# Out:
# 1825
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %% [markdown]
# ##### There are total 1825 different cuisines

# %% [markdown]
# #

# %%
#Plotting top 10 most sold cuisines 
plt.figure(figsize=(10,5))
df.Cuisines.value_counts()[0:10].plot(kind='barh', color = 'g')
plt.xlabel('Count')
plt.title('Cuisines\n')
# Out:
# Text(0.5, 1.0, 'Cuisines\n')

# %% [markdown]
# #### North Indian and Chinese are most preferrd cuisines

# %% [markdown]
# #

# %%
#Plotting top 10 most sold cuisines on online delivery
plt.figure(figsize=(10,5))
df[df['Has Online delivery'] == 'Yes'].Cuisines.value_counts()[0:10].plot(kind='barh', color = 'r')
plt.xlabel('Count')
plt.title('Cuisines ordered online\n')
# Out:
# Text(0.5, 1.0, 'Cuisines ordered online\n')

# %% [markdown]
# ##### North Indian items with different varieties are among the top 4 most sold items

# %% [markdown]
# #

# %%
#Plotting top 10 most preferred cuisines in USA
plt.figure(figsize=(10,5))
df[df['Country']=='United States'].Cuisines.value_counts()[0:10].plot(kind='barh', color = 'g')
plt.xlabel('Count')
plt.title('Cuisines (USA) \n')
# Out:
# Text(0.5, 1.0, 'Cuisines (USA) \n')

# %% [markdown]
# ##### Mexican Cusine is most preferred one in US

# %% [markdown]
# #

# %%
#Plotting top 10 most preferred cuisines in United Kingdom
plt.figure(figsize=(10,5))
df[df['Country']=='United Kingdom'].Cuisines.value_counts()[0:10].plot(kind='barh', color = 'b')
plt.xlabel('Count')
plt.title('Cuisines (UK) \n')
# Out:
# Text(0.5, 1.0, 'Cuisines (UK) \n')

# %% [markdown]
# ##### Italian Cusine is most preferred one in United Kingdom

# %% [markdown]
# #

# %%
#Average cost for 2 per Cuisine
Cuisine_avg_cost = df.groupby('Cuisines').mean()[['Average Cost for two']].reset_index()
Cuisine_avg_cost.sort_values(by='Average Cost for two',ascending=False,inplace=True)
Cuisine_avg_cost[0:10].plot(kind='barh',x='Cuisines',y='Average Cost for two')
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %%
#Average Price Range in India for top 10 Cuisines
df_india = df[df['Country']=='India']
Cuisine_avg_cost = df_india.groupby('Cuisines').mean()[['Price range']].reset_index()
Cuisine_avg_cost.sort_values(by='Price range',ascending=False,inplace=True)
Cuisine_avg_cost[0:10].plot(kind='barh',x='Cuisines',y='Price range')
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %%
#Cusines with highest number of votes
cusine_votes = df_india.groupby('Cuisines').sum()[['Votes']].reset_index()
cusine_votes.sort_values(by='Votes',ascending=False,inplace=True)
cusine_votes[0:10].plot(kind='barh',x='Cuisines',y='Votes',color='g',legend=False)
plt.title("Top ten Cusines with most number of Votes\n")
# Out:
# Text(0.5, 1.0, 'Top ten Cusines with most number of Votes\n')

# %% [markdown]
# ##### North Indian and Chinese cuisines have been most voted

# %% [markdown]
# #

# %% [markdown]
# ### Restaurants

# %%
#Average Price Range in India for top 10 restaurants
plt.figure(figsize=(10,8))
restaurant_avg_cost = df_india.groupby('Restaurant Name').mean()[['Average Cost for two']].reset_index()
restaurant_avg_cost.sort_values(by='Average Cost for two',ascending=False,inplace=True)
restaurant_avg_cost[0:10].plot(kind='barh',x='Restaurant Name',y='Average Cost for two')
# Out:
# <AxesSubplot:ylabel='Restaurant Name'>

# %%
#Best rated cusines
cusine_votes = df_india.groupby('Cuisines').sum()[['Votes']].reset_index()
cusine_votes.sort_values(by='Votes',ascending=False,inplace=True)
cusine_votes[0:10].plot(kind='barh',x='Cuisines',y='Votes',color='g',legend=False)
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %% [markdown]
# #

# %% [markdown]
# ### Table Booking

# %%
print(df['Has Table booking'].value_counts())
df['Has Table booking'].value_counts().plot(kind = 'pie')
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64
# <AxesSubplot:ylabel='Has Table booking'>

# %% [markdown]
# ##### Most of the restaurants doesnt have table booking

# %% [markdown]
# #

# %%
#Average price when there is booking vs no booking
df_india.groupby(['Has Table booking']).mean()[['Average Cost for two']].plot(kind='bar',legend=False,color='r')
plt.title('Average cost for 2 \n')
# Out:
# Text(0.5, 1.0, 'Average cost for 2 \n')

# %%
#Average price when there is online delivery vs no online delivery
df_india.groupby(['Has Online delivery']).mean()[['Average Cost for two']].plot(kind='bar',legend=False,color='g')
plt.title('Average cost for 2 \n')
# Out:
# Text(0.5, 1.0, 'Average cost for 2 \n')

# %% [markdown]
# ##### Average cost for 2 increases by 100 rs if the restaurant has online delivery option

# %% [markdown]
# #

# %%
#Price distribution
plt.figure(figsize=(10,5))
df_india['Average Cost for two'].hist(bins=80)
plt.title("Average cost for 2 \n")
# Out:
# Text(0.5, 1.0, 'Average cost for 2 \n')

# %%
df_india['Average Cost for two'].describe().reset_index()
# Out:
#    index  Average Cost for two
# 0  count           8652.000000
# 1   mean            623.370319
# 2    std            595.676124
# 3    min              0.000000
# 4    25%            300.000000
# 5    50%            450.000000
# 6    75%            700.000000
# 7    max           8000.000000

# %% [markdown]
# ##### The average price is India is 623 and 50% of the people spend less than 450 for 2 people meal

# %% [markdown]
# #

# %%
#Votes distribution
plt.figure(figsize=(10,5))
df_india['Votes'].hist(bins = 80)
plt.title("Votes \n")
# Out:
# Text(0.5, 1.0, 'Votes \n')

# %%
#Impact of no of votes on price 
df_india.plot.scatter(y='Average Cost for two',x='Votes')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Votes', ylabel='Average Cost for two'>

# %% [markdown]
# ##### Votes doesnt have impact on price

# %% [markdown]
# #

# %%
#Checking correlation between price and rating
df_india.plot.scatter(y='Average Cost for two',x='Aggregate rating',color='r')
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %% [markdown]
# ##### The above data points show that there is no significant relationship between price and rating but there is some relationhip which can be studied with deep analysis
